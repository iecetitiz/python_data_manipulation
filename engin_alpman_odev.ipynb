# %% [markdown]
# **soru -->** 10 uzunluklu sifirlardan olusan 1-D array olustur
#
# **soru -->** 5 uzunluklu float sifirlardan olusan 1-D olustur
#
# **soru -->** 15 uzunluklu string sifirlardan olusan 1-D olustur
#
# **soru -->** hem folat hem de int'lerden olusan(ayri ayri olustur) 2-D arrayler olustur uzunluklari (3, 4) olsun
#
# **soru -->** (3,4) boyutlarinda string olarak bos ve bool olarak hem true hem de false 2-D array olustur
#
# **soru -->** (5,5) boyutlarinda 8'lerden olusan bir matrix olustur ve bir tane de 9 uzunluklu 10'lardan olusan bir vector olustur
#
# **soru -->** bir python list'i 4 defa yan yana eklenecek sekilde baska bir list'e aktar
#
# **soru -->** numpy arrayleri element-wise olarak topla ve carp
#
# **soru -->** bir numpy arrayi tum elemanlari 3 katina cikacak sekilde guncelle
#
#
# # Multidimensional Arraylerde Indexleme ve Slice
#
# **soru -->** bir matrixten 2.satiri getir ve bu gelenin dimensionanunu sorgula
#
# **soru -->** bir matrixten 3.sutunu getir ve bu gelenin dimensionanunu sorgula
#
# **soru -->** bir matrixin 4.satir ve 5.sutunundaki elemani getir, bunu yaparken iki turlu bi yapim var ikisiyle de dene
#
# **soru -->** matrixin bir elemanini degistir
#
# **soru -->** integer tutan bir matrixin bir elemanini float ile degistir, bir de string ile degistir ve
# sonucta neyin degistigine bak
# **soru -->** string halde bir float degeri eleman olarak eklemeye calis
#
# **soru -->** bir matrisin ilk 3 satirini al
#
# **soru -->** bir matrisin son 3 satirini al
#
# **soru -->** bir matrisin ilk 3 sutununu al
#
# **soru -->** bir matrisin tum satirlarini al ama ikiser ikiser atlayarak al
#
# **soru -->** bir matrisin tum satirlarini al ama sadece 2.sutunu getir
#
# **soru -->** bir matrisin tum sutunlarini al ama sadece 3.satiri gelsin ve bu donen son iki seyin shape'ine bak
#
# **soru -->** bir matrisin tum sutunlarini al ama sadece 3.satiri 2'ser 2'ser atlayarak gelsin ve bu donen son
# iki seyin shape'ine bak
#
# **soru -->** bir matrisin sol ust kosesiyle sag alt kosesini yan yana ve alt alta birlestir
#
# **soru -->** arange ile 20 uzunluklu bir array yarat ve 3, 5, 6, 7, 1.indexteki elemanlari bu sirayla al
#
# **soru -->** bir matrix yarat ve rowlari fancy index'le columnlari slice ile al
#
# **soru -->** bir matrix yarat ve rowlari slice ile columnlari fancy indexle al
#
# **soru -->** bir matrix yarat ve rowlari slice ile columnu sayi ile al ve shapeine bak
#
# **soru -->** bir matrix yarat ve fancy index ile 3X2'lik bir matrix dondur
#
# **soru -->** bir matrix yarat ve hem row'u hem column'u fancy index ile dondur ne verdigine bak, shape'ine de bak
#
# **soru -->** bir matrix yarat ve fancy index ile 1, 2, 5.satirlari dondur a[1, 2, 5]
#
# **soru -->** bir array yarat ve fancy index ile 1, 2, 5.elemanlari 20 yap
#
# **soru -->** bir array yarat ve fancy index ile 1, 2, 5.elemanlari sirayla 200, 300 ve 400 yap
#
# # Subarray
#
#
# **soru -->** bir matrix yarat ve o matrixten bir submatrixi once kendisini degistirebilecek bir parca kes, sonra onu degistiremeyecek bir parca kes
