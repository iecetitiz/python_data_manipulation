# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # distplot()

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(df["tip"])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df["size"])
# Out:
# <AxesSubplot: xlabel='size', ylabel='Count'>

# %%
sns.histplot(df["tip"])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df["tip"], bins = 50)
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
sns.set(style = "darkgrid", font_scale = 1.5)
sns.distplot(df["total_bill"], bins = 50, color = "green", hist = False, kde_kws = {"shade": True}, rug = True)
#kde = True cizgiyi gosteriyor
# Out:
# C:\Users\iecet\AppData\Local\Temp\ipykernel_17456\2875502348.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], bins = 50, color = "green", hist = False, kde_kws = {"shade": True}, rug = True)
# C:\Users\iecet\anaconda3\lib\site-packages\seaborn\distributions.py:2511: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
sns.set(style = "whitegrid", font_scale = 1.5)
fig, axes = plt.subplots(2, 2, figsize = (10, 10))
sns.distplot(df["size"], ax = axes[0,0]) # ax ile belirttigim yer grafigin konumu olacak
sns.distplot(df["total_bill"], bins = 50, kde = False, color = "blue", ax = axes[0,1])
sns.distplot(df["total_bill"], bins = 50, kde = False, color = "red", ax = axes[1,0])
sns.distplot(df["total_bill"], bins = 50, color = "green", hist = False, kde_kws = {"shade": True}, rug = True, ax = axes[1,1])
plt.tight_layout()
# Out:
# C:\Users\iecet\AppData\Local\Temp\ipykernel_17456\413975454.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["size"], ax = axes[0,0]) # ax ile belirttigim yer grafigin konumu olacak
# C:\Users\iecet\AppData\Local\Temp\ipykernel_17456\413975454.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # jointplot()
# **iki degisken arasindaki iliskiye bakicam**

# %%
sns.jointplot(x = df["tip"], y = df["total_bill"])

# %%
sns.jointplot(x = "size", y = "tip", data = df, kind = "hex", color = "r")

# %%
sns.jointplot(x = "size", y = "tip", data = df, kind = "reg", color = "r")

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = "reg", color = "r")

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = "reg", color = "r", ylim = (0, 5), xlim = (0, 20))

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df, kind = "kde", color = "r", ylim = (0, 5), xlim = (0, 20))

# %% [markdown]
# # kdeplot
#
# **azonce attribute olarak verdigim kde'nin kendi plotu var**

# %%
sns.kdeplot(df["tip"])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x = df["total_bill"], y = df["tip"], color = "red", shade = True)
# Out:
# C:\Users\iecet\AppData\Local\Temp\ipykernel_17456\1208004594.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = df["total_bill"], y = df["tip"], color = "red", shade = True)
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # pairplot()
#
# **tum sayisal degiskenleri kendi aralarinda iliskilendiriyor**

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue = "sex") #su ana kadar hep sayisal degiskenlerle calistik ama simdi bu iliksiye kategorik degisken de eklendi

# %%
sns.pairplot(df, hue = "smoker")

# %% [markdown]
# # boxplot()
#
# **istatistiksel bir gorunum verecek**

# %%
sns.boxplot(x = "sex", y = "tip", data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = "sex", y = "tip", data = df, width = 0.5)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
sns.boxplot(x = "sex", y = "tip", hue = "day", data = df, width = 0.5)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %% [markdown]
# # violinplot()

# %%
sns.violinplot(x = "sex", y = "tip", data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x = "sex", y = "tip", hue = "day", data = df)
plt.tight_layout()
# yukariya dogru uzadigi yerler uc aykiri degerler gibi dusunebilirim

# %%
sns.violinplot(x = "sex", y = "tip", hue = "time", data = df)
plt.tight_layout()

# %%
sns.violinplot(x = "day", y = "tip", hue = "time", data = df)
plt.tight_layout()
#persembe gunu hic aksam yemegi yenmemis mesela ilginc
#cumartesi pazar da ogle yemegi yok

# %% [markdown]
# # barplot() and countplot()
# **countplot() herhangi bir kategorik degiskenin frekansini gosteriyor**

# %%
sns.barplot(x = "sex", y = "tip", hue = "smoker", data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x = "sex", y = "tip", hue = "time", data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x = "sex", y = "tip", hue = "day", data = df)
plt.tight_layout()
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x = df["sex"], hue = "smoker", data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = df["day"], hue = "smoker", data = df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
sns.countplot(x = df["day"], hue = "sex", data = df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %% [markdown]
# # factorplot()

# %%
sns.catplot(x = "sex", y = "tip", data = df)

# %%
sns.catplot(x = "sex", y = "tip", data = df, kind = "bar")

# %%
sns.catplot(x = "sex", y = "tip", data = df, kind = "box")

# %%
sns.catplot(x = "sex", y = "tip", data = df, kind = "box", hue = "day")

# %%
sns.catplot(x = "time", y = "tip", data = df, kind = "box", hue = "day")

# %% [markdown]
# # heatmap()
# **asiri guzel bi grafik, istedigim iki degeri matrisel bir formda yaziyorum**

# %%
df2 = df.pivot_table(index = "size", columns = "day", values = "tip")

# %%
df2
# Out:
# day     Thur       Fri       Sat       Sun
# size
# 1     1.8300  1.920000  1.000000       NaN
# 2     2.4425  2.644375  2.517547  2.816923
# 3     2.6925  3.000000  3.797778  3.120667
# 4     4.2180  4.730000  4.123846  4.087778
# 5     5.0000       NaN  3.000000  4.046667
# 6     5.3000       NaN       NaN  5.000000

# %%
sns.heatmap(df2)
#bu bir sicaklik grafigi, renkler acildikca sayilarin buyudugunu ve iliskinin guclendigini gorebiliyorum
# Out:
# <AxesSubplot: xlabel='day', ylabel='size'>

# %%
sns.heatmap(df2, annot = True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='size'>

# %%
sns.heatmap(df2, annot = True, linecolor = "black", lw = 0.5)
# Out:
# <AxesSubplot: xlabel='day', ylabel='size'>

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df3 = df.corr()
#korelasyonu veriyor

# %%
sns.heatmap(df3)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # lmplot()
# **degiskenler arasindaki dogrusalligi sagliyor**

# %%
sns.lmplot(x = "tip", y = "total_bill", data = df)

# %%
sns.lmplot(x = "tip", y = "total_bill", data = df, hue = "sex")

# %%
sns.lmplot(x = "tip", y = "total_bill", data = df, hue = "day")

# %%
sns.lmplot(x = "size", y = "total_bill", data = df, hue = "day")

# %%
sns.lmplot(x = "size", y = "total_bill", data = df, hue = "sex")
